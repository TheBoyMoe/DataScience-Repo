# %% [markdown]
# # Pandas Review
#
# Create pandas from:
#
# **1. python dictionary**

# %%
import numpy as np
import pandas as pd

my_dict = {
    'id': [1,2,3,4],
    'name': ['ringo', 'paul', 'john', 'george'],
    'age': [23,24,25,26],
    'role': ['drummer', 'singer', 'singer', 'guitar']
}
df_beatles = pd.DataFrame(my_dict)
df_beatles
# Out:
#    id    name  age     role
# 0   1   ringo   23  drummer
# 1   2    paul   24   singer
# 2   3    john   25   singer
# 3   4  george   26   guitar

# %% [markdown]
# **2. python list**

# %%
lst = [[1,2,3], ['tom', 'dick', 'harry'], [23,24,25]]
cols = ['id', 'name', 'age']
df_lst = pd.DataFrame(lst, cols)
df_lst
# Out:
#         0     1      2
# id      1     2      3
# name  tom  dick  harry
# age    23    24     25

# %% [markdown]
# **3. csv file**
#
# General format:
#
# ```py
# df = pd.read_csv('file_name.csv', nrows=5, header=None, sep=',', comment='#', na_values=[''])
# ```
# The 1st argument, filename(path), is req'd, the others are optional:
#
# - `nrows` number of rows of file to read.
# - `header=None` use row number as the column names.
# - `sep` delimiter to use, default `sep` is a comma, `,`.
# - `comment` character to split comments.
# - `na_values` string to regognise as NaN.

# %%
df = pd.read_csv('data/test.csv')

# %% [markdown]
# ## Exploring a Pandas DataFrame

# %%
df.index
# Out:
# RangeIndex(start=0, stop=418, step=1)

# %%
# return the column headings
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# dataframe info - num cols, num rows, num non-num values for each row, col data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
# return the first x rows, default is 5
df.head(2)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S

# %%
# return the last 'x' rows, default is 5
df.tail(2)
# Out:
#      PassengerId  Pclass                      Name   Sex  Age  SibSp  Parch  \
# 416         1308       3       Ware, Mr. Frederick  male  NaN      0      0
# 417         1309       3  Peter, Master. Michael J  male  NaN      1      1
#
#      Ticket     Fare Cabin Embarked
# 416  359309   8.0500   NaN        S
# 417    2668  22.3583   NaN        C

# %%
# return a numpy array of all the values
# dataframe of mixed datatypes results in a numpy array of objects
df_array = df.values
df_array
# Out:
# array([[892, 3, 'Kelly, Mr. James', ..., 7.8292, nan, 'Q'],
#        [893, 3, 'Wilkes, Mrs. James (Ellen Needs)', ..., 7.0, nan, 'S'],
#        [894, 2, 'Myles, Mr. Thomas Francis', ..., 9.6875, nan, 'Q'],
#        ...,
#        [1307, 3, 'Saether, Mr. Simon Sivertsen', ..., 7.25, nan, 'S'],
#        [1308, 3, 'Ware, Mr. Frederick', ..., 8.05, nan, 'S'],
#        [1309, 3, 'Peter, Master. Michael J', ..., 22.3583, nan, 'C']],
#       dtype=object)

# %% [markdown]
# ### Select a Subsection/Row(s) of a Pandas DataFrame or Series
#
# A Series is a 1-D array, use `[start:end]` notation as you do with Python lists.
#
# You can also use the same notation to select a subsection of a dataframe, `start` and `end` referring to rows.
#
# When selecting a single row, use `.iloc`

# %%
# select a Single row
df.iloc[205]
# Out:
# PassengerId                         1097
# Pclass                                 1
# Name           Omont, Mr. Alfred Fernand
# Sex                                 male
# Age                                  NaN
# SibSp                                  0
# Parch                                  0
# Ticket                        F.C. 12998
# Fare                             25.7417
# Cabin                                NaN
# Embarked                               C
# Name: 205, dtype: object

# %%
# Select Multiple rows, starting at row 205, upto but not including row 210
df[205: 210] # or df.iloc[205:210]
# Out:
#      PassengerId  Pclass                           Name     Sex   Age  SibSp  \
# 205         1097       1      Omont, Mr. Alfred Fernand    male   NaN      0
# 206         1098       3       McGowan, Miss. Katherine  female  35.0      0
# 207         1099       2   Collett, Mr. Sidney C Stuart    male  24.0      0
# 208         1100       1  Rosenbaum, Miss. Edith Louise  female  33.0      0
# 209         1101       3             Delalic, Mr. Redjo    male  25.0      0
#
#      Parch      Ticket     Fare Cabin Embarked
# 205      0  F.C. 12998  25.7417   NaN        C
# 206      0        9232   7.7500   NaN        Q
# 207      0       28034  10.5000   NaN        S
# 208      0    PC 17613  27.7208   A11        C
# 209      0      349250   7.8958   NaN        S

# %%
# starting from 3rd from end, going from back to front(right to left),
# upto but not including row 410 (-8 from back)
df[-3:-8:-1] # or df.iloc[-3:-8:-1]
# Out:
#      PassengerId  Pclass                                             Name  \
# 415         1307       3                     Saether, Mr. Simon Sivertsen
# 414         1306       1                     Oliva y Ocana, Dona. Fermina
# 413         1305       3                               Spector, Mr. Woolf
# 412         1304       3                   Henriksson, Miss. Jenny Lovisa
# 411         1303       1  Minahan, Mrs. William Edward (Lillian E Thorpe)
#
#         Sex   Age  SibSp  Parch              Ticket     Fare Cabin Embarked
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.250   NaN        S
# 414  female  39.0      0      0            PC 17758  108.900  C105        C
# 413    male   NaN      0      0           A.5. 3236    8.050   NaN        S
# 412  female  28.0      0      0              347086    7.775   NaN        S
# 411  female  37.0      1      0               19928   90.000   C78        Q

# %% [markdown]
# ### Select a Single Column

# %%
# select a column of data - limit return to 1st 5 rows
# returns a pandas 'Series' when selecting a 'Single' column
# select elements same as a python list
df.Name[:5]
# Out:
# 0                                Kelly, Mr. James
# 1                Wilkes, Mrs. James (Ellen Needs)
# 2                       Myles, Mr. Thomas Francis
# 3                                Wirz, Mr. Albert
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# Name: Name, dtype: object

# %%
# use [''] when key name contains spaces, special chars or starts with a number
df['Name'][5:9]
# Out:
# 5                   Svensson, Mr. Johan Cervin
# 6                         Connolly, Miss. Kate
# 7                 Caldwell, Mr. Albert Francis
# 8    Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# Name: Name, dtype: object

# %% [markdown]
# ### Select Multiple Columns

# %%
# Use a comma separated list of column names.
df[['Name', 'Age', 'Pclass']][16:21]
# Out:
#                                      Name   Age  Pclass
# 16                      Keane, Mr. Daniel  35.0       2
# 17                      Assaf, Mr. Gerios  21.0       3
# 18           Ilmakangas, Miss. Ida Livija  27.0       3
# 19  Assaf Khalil, Mrs. Mariana (Miriam")"  45.0       3
# 20                 Rothschild, Mr. Martin  55.0       1

# %% [markdown]
# ### Select an individual field/value

# %%
# NOTE: rows and columns are ZERO indexed
# Select the field by position, row(0) & column(2), uses 'iloc'
df.iloc[[0], [2]]
# Out:
#                Name
# 0  Kelly, Mr. James

# %%
# Select the field by Label, uses 'loc'
df.loc[[0], ['Name']]
# Out:
#                Name
# 0  Kelly, Mr. James

# %% [markdown]
# ### Dropping Columns

# %%
# NOTE: use 'axis=1' to drop a column, original dataframe is unchanged
# use a comma separated list of one or more column names
# drop a single column from a dataframe
df.drop(['PassengerId', 'SibSp', 'Parch'], axis=1)[200:210]
# Out:
#      Pclass                                     Name     Sex    Age  \
# 200       3                       Murphy, Miss. Nora  female    NaN
# 201       3  Danbom, Master. Gilbert Sigvard Emanuel    male   0.33
# 202       1                   Astor, Col. John Jacob    male  47.00
# 203       2               Quick, Miss. Winifred Vera  female   8.00
# 204       2                 Andrew, Mr. Frank Thomas    male  25.00
# 205       1                Omont, Mr. Alfred Fernand    male    NaN
# 206       3                 McGowan, Miss. Katherine  female  35.00
# 207       2             Collett, Mr. Sidney C Stuart    male  24.00
# 208       1            Rosenbaum, Miss. Edith Louise  female  33.00
# 209       3                       Delalic, Mr. Redjo    male  25.00
#
#          Ticket      Fare    Cabin Embarked
# 200       36568   15.5000      NaN        Q
# 201      347080   14.4000      NaN        S
# 202    PC 17757  227.5250  C62 C64        C
# 203       26360   26.0000      NaN        S
# 204  C.A. 34050   10.5000      NaN        S
# 205  F.C. 12998   25.7417      NaN        C
# 206        9232    7.7500      NaN        Q
# 207       28034   10.5000      NaN        S
# 208    PC 17613   27.7208      A11        C
# 209      349250    7.8958      NaN        S

# %% [markdown]
# ### Dropping Rows

# %%
# NOTE: use 'axis=0' to drop a row, original dataframe remains unchanged
# drop rows based on row number
df.drop([204, 205, 206], axis=0)[200:210]
# Out:
#      PassengerId  Pclass                                     Name     Sex  \
# 200         1092       3                       Murphy, Miss. Nora  female
# 201         1093       3  Danbom, Master. Gilbert Sigvard Emanuel    male
# 202         1094       1                   Astor, Col. John Jacob    male
# 203         1095       2               Quick, Miss. Winifred Vera  female
# 207         1099       2             Collett, Mr. Sidney C Stuart    male
# 208         1100       1            Rosenbaum, Miss. Edith Louise  female
# 209         1101       3                       Delalic, Mr. Redjo    male
# 210         1102       3              Andersen, Mr. Albert Karvin    male
# 211         1103       3                        Finoli, Mr. Luigi    male
# 212         1104       2                Deacon, Mr. Percy William    male
#
#        Age  SibSp  Parch              Ticket      Fare    Cabin Embarked
# 200    NaN      0      0               36568   15.5000      NaN        Q
# 201   0.33      0      2              347080   14.4000      NaN        S
# 202  47.00      1      0            PC 17757  227.5250  C62 C64        C
# 203   8.00      1      1               26360   26.0000      NaN        S
# 207  24.00      0      0               28034   10.5000      NaN        S
# 208  33.00      0      0            PC 17613   27.7208      A11        C
# 209  25.00      0      0              349250    7.8958      NaN        S
# 210  32.00      0      0              C 4001   22.5250      NaN        S
# 211    NaN      0      0  SOTON/O.Q. 3101308    7.0500      NaN        S
# 212  17.00      0      0        S.O.C. 14879   73.5000      NaN        S

# %% [markdown]
# ### Selecting a subset based on logic

# %%
df[(df.Age > 60) & (df.Sex == 'female')]
# Out:
#      PassengerId  Pclass                                               Name  \
# 96           988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 114         1006       1             Straus, Mrs. Isidor (Rosalie Ida Blun)
# 179         1071       1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# 305         1197       1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
#
#         Sex   Age  SibSp  Parch    Ticket      Fare    Cabin Embarked
# 96   female  76.0      1      0     19877   78.8500      C46        S
# 114  female  63.0      1      0  PC 17483  221.7792  C55 C57        S
# 179  female  64.0      0      2  PC 17756   83.1583      E45        C
# 305  female  64.0      1      1    112901   26.5500      B26        S

# %%
df[(df.Age > 55) & (df.Age < 60) & ((df.Pclass == 1) | (df.Pclass == 2)) ]
# Out:
#      PassengerId  Pclass                                               Name  \
# 217         1109       1                           Wick, Mr. George Dennick
# 316         1208       1                      Spencer, Mr. William Augustus
# 343         1235       1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 356         1248       1     Brown, Mrs. John Murray (Caroline Lane Lamson)
# 387         1279       2                                    Ashby, Mr. John
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 217    male  57.0      1      1     36928  164.8667          NaN        S
# 316    male  57.0      1      0  PC 17569  146.5208          B78        C
# 343  female  58.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 356  female  59.0      2      0     11769   51.4792         C101        S
# 387    male  57.0      0      0    244346   13.0000          NaN        S

# %% [markdown]
# When we select a subset of a DataFrame using logic, we end up with non-consecutive indices. We can fix this using the method `.reset_index()`.
#
# By default, a new `index` column is created with the old indicies and and the indicies reset. You can avoid the `index` column being created by using the `drop=True` option.

# %%
df[(df.Age > 40) & (df.Age < 45) & (df.Pclass == 1)].reset_index(drop=True)
# Out:
#    PassengerId  Pclass                                               Name  \
# 0          920       1                            Brady, Mr. John Bertram
# 1          992       1  Stengel, Mrs. Charles Emil Henry (Annie May Mo...
# 2         1036       1  Lindeberg-Lind, Mr. Erik Gustaf (Mr Edward Lin...
# 3         1050       1                           Borebank, Mr. John James
# 4         1107       1                              Head, Mr. Christopher
# 5         1137       1                            Kenyon, Mr. Frederick R
# 6         1296       1                       Frauenthal, Mr. Isaac Gerald
#
#       Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 0    male  41.0      0      0  113054  30.5000   A21        S
# 1  female  43.0      1      0   11778  55.4417  C116        C
# 2    male  42.0      0      0   17475  26.5500   NaN        S
# 3    male  42.0      0      0  110489  26.5500   D22        S
# 4    male  42.0      0      0  113038  42.5000   B11        S
# 5    male  41.0      1      0   17464  51.8625   D21        S
# 6    male  43.0      1      0   17765  27.7208   D40        C
