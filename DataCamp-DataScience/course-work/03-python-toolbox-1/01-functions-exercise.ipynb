# %% [markdown]
# # Functions Exercise

# %%
import pandas as pd

df = pd.read_csv('tweets.csv', index_col='id')
df.head(2)
# Out:
#                     contributors  coordinates                      created_at  \
# id
# 714960401759387648           NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 714960401977319424           NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
#
#                                                              entities  \
# id
# 714960401759387648  {'hashtags': [], 'user_mentions': [{'screen_na...
# 714960401977319424  {'hashtags': [{'text': 'cruzsexscandal', 'indi...
#
#                                                     extended_entities  \
# id
# 714960401759387648  {'media': [{'sizes': {'large': {'w': 1024, 'h'...
# 714960401977319424  {'media': [{'sizes': {'large': {'w': 500, 'h':...
#
#                     favorite_count  favorited filter_level  geo  \
# id
# 714960401759387648               0      False          low  NaN
# 714960401977319424               0      False          low  NaN
#
#                                 id_str  \
# id
# 714960401759387648  714960401759387648
# 714960401977319424  714960401977319424
#
#                                           ...                          \
# id                                        ...
# 714960401759387648                        ...
# 714960401977319424                        ...
#
#                    quoted_status_id  quoted_status_id_str  retweet_count  \
# id
# 714960401759387648              NaN                   NaN              0
# 714960401977319424              NaN                   NaN              0
#
#                     retweeted  \
# id
# 714960401759387648      False
# 714960401977319424      False
#
#                                                      retweeted_status  \
# id
# 714960401759387648  {'retweeted': False, 'text': ".@krollbondratin...
# 714960401977319424  {'retweeted': False, 'text': '@dmartosko Cruz ...
#
#                                                                source  \
# id
# 714960401759387648  <a href="http://twitter.com" rel="nofollow">Tw...
# 714960401977319424  <a href="http://twitter.com" rel="nofollow">Tw...
#
#                                                                  text  \
# id
# 714960401759387648  RT @bpolitics: .@krollbondrating's Christopher...
# 714960401977319424  RT @HeidiAlpine: @dmartosko Cruz video found.....
#
#                      timestamp_ms truncated  \
# id
# 714960401759387648  1459294817758     False
# 714960401977319424  1459294817810     False
#
#                                                                  user
# id
# 714960401759387648  {'utc_offset': 3600, 'profile_image_url_https'...
# 714960401977319424  {'utc_offset': None, 'profile_image_url_https'...
#
# [2 rows x 30 columns]

# %%
# Initialize an empty dictionary: langs_count
langs_count = {}

# Extract column from DataFrame: col
col = df['lang']

# Iterate over lang column in DataFrame
for entry in col:

    # If the language is in langs_count, add 1
    if entry in langs_count.keys():
        langs_count[entry] += 1
    # Else add the language to langs_count, set the value to 1
    else:
        langs_count[entry] = 1

# Print the populated dictionary
print(langs_count)
# Out:
# {'en': 97, 'et': 1, 'und': 2}

# %%
# Define count_entries()
def count_entries(df, col_name):
    """Return a dictionary with counts of 
    occurrences as value for each key."""

    # Initialize an empty dictionary: langs_count
    langs_count = {}
    
    # Extract column from DataFrame: col
    col = df[col_name]
    
    # Iterate over lang column in DataFrame
    for entry in col:

        # If the language is in langs_count, add 1
        if entry in langs_count.keys():
            langs_count[entry] += 1
        # Else add the language to langs_count, set the value to 1
        else:
            langs_count[entry] = 1

    # Return the langs_count dictionary
    return langs_count

# Call count_entries(): result
result = count_entries(df, 'lang')

# Print the result
print(result)
# Out:
# {'en': 97, 'et': 1, 'und': 2}
