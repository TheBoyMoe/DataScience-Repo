# %% [markdown]
# # Pandas Basics

# %% [markdown]
# ### Creating pandas dataframes

# %%
import pandas as pd
import numpy as np

# 1. using dicts
dic = {
    'name': ['Tom Jones', 'Dick Jones', 'Harry Jones'],
    'age': [23,34,45],
    'employed': [True, False, True]
}
df = pd.DataFrame(dic)
df
# Out:
#           name  age  employed
# 0    Tom Jones   23      True
# 1   Dick Jones   34     False
# 2  Harry Jones   45      True

# %%
# apply custom index
df.index = list('xyz')
df
# Out:
#           name  age  employed
# x    Tom Jones   23      True
# y   Dick Jones   34     False
# z  Harry Jones   45      True

# %%
# 2. using ndarray or 2D python list
ndarray = np.array([
    list('123456'), # each list represents a row, must be same length
    list('abcdef'),
    list('qurstu')
])
names = ['ab','bc', 'cd', 'de', 'ef', 'fg']

pd.DataFrame(ndarray, columns=names)
# Out:
#   ab bc cd de ef fg
# 0  1  2  3  4  5  6
# 1  a  b  c  d  e  f
# 2  q  u  r  s  t  u

# %%
# apply a custom index col
pd.DataFrame(ndarray, columns=names, index=list('xyz'))
# Out:
#   ab bc cd de ef fg
# x  1  2  3  4  5  6
# y  a  b  c  d  e  f
# z  q  u  r  s  t  u

# %%
# 3. reading a file
pd.read_csv('../data/cars.csv', index_col=0)
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %%
df = pd.read_csv('../data/percent-bachelors-degrees-women-usa.csv')
print(df.shape)
df.head().T
# Out:
# (42, 18)
#                                          0            1            2  \
# Year                           1970.000000  1971.000000  1972.000000
# Agriculture                       4.229798     5.452797     7.420710
# Architecture                     11.921005    12.003106    13.214594
# Art and Performance              59.700000    59.900000    60.400000
# Biology                          29.088363    29.394403    29.810221
# Business                          9.064439     9.503187    10.558962
# Communications and Journalism    35.300000    35.500000    36.600000
# Computer Science                 13.600000    13.600000    14.900000
# Education                        74.535328    74.149204    73.554520
# Engineering                       0.800000     1.000000     1.200000
# English                          65.570923    64.556485    63.664263
# Foreign Languages                73.800000    73.900000    74.600000
# Health Professions               77.100000    75.500000    76.900000
# Math and Statistics              38.000000    39.000000    40.200000
# Physical Sciences                13.800000    14.900000    14.800000
# Psychology                       44.400000    46.200000    47.600000
# Public Administration            68.400000    65.500000    62.600000
# Social Sciences and History      36.800000    36.200000    36.100000
#
#                                          3            4
# Year                           1973.000000  1974.000000
# Agriculture                       9.653602    14.074623
# Architecture                     14.791613    17.444688
# Art and Performance              60.200000    61.900000
# Biology                          31.147915    32.996183
# Business                         12.804602    16.204850
# Communications and Journalism    38.400000    40.500000
# Computer Science                 16.400000    18.900000
# Education                        73.501814    73.336811
# Engineering                       1.600000     2.200000
# English                          62.941502    62.413412
# Foreign Languages                74.900000    75.300000
# Health Professions               77.400000    77.900000
# Math and Statistics              40.900000    41.800000
# Physical Sciences                16.500000    18.200000
# Psychology                       50.400000    52.600000
# Public Administration            64.300000    66.100000
# Social Sciences and History      36.400000    37.300000

# %% [markdown]
# **Selecting rows based on position**
#
# Use `iloc` method to select rows from a dataframe.

# %%
df.iloc[-28:-23] # similar to slicing lists
# Out:
#     Year  Agriculture  Architecture  Art and Performance    Biology  \
# 14  1984    31.092947     35.453083                 62.1  47.669083
# 15  1985    31.379659     36.133348                 61.8  47.909884
# 16  1986    31.198719     37.240223                 62.1  48.300678
# 17  1987    31.486429     38.730675                 61.7  50.209878
# 18  1988    31.085087     39.398907                 61.7  50.099811
#
#      Business  Communications and Journalism  Computer Science  Education  \
# 14  45.124030                           59.1              36.8  75.869116
# 15  45.747782                           59.0              35.7  75.923440
# 16  46.532915                           60.0              34.7  76.143015
# 17  46.690466                           60.2              32.4  76.963092
# 18  46.764828                           60.4              30.8  77.627662
#
#     Engineering    English  Foreign Languages  Health Professions  \
# 14         13.5  65.749862               72.1                85.1
# 15         13.5  65.798199               70.8                85.3
# 16         13.9  65.982561               71.2                85.7
# 17         14.0  66.706031               72.0                85.5
# 18         13.9  67.144498               72.3                85.2
#
#     Math and Statistics  Physical Sciences  Psychology  Public Administration  \
# 14                 46.2               28.0        68.2                   75.9
# 15                 46.5               27.5        69.0                   75.0
# 16                 46.7               28.4        69.0                   75.7
# 17                 46.5               30.4        70.1                   76.4
# 18                 46.2               29.7        70.9                   75.6
#
#     Social Sciences and History
# 14                         44.1
# 15                         43.8
# 16                         44.0
# 17                         43.9
# 18                         44.4

# %%
df[['Biology', 'Education', 'English', 'Business']].iloc[10:15]
# Out:
#       Biology  Education    English   Business
# 10  43.999257  74.981032  65.284130  36.765725
# 11  45.249512  75.845123  65.838322  39.266230
# 12  45.967338  75.843649  65.847352  41.949373
# 13  46.713135  75.950601  65.918380  43.542070
# 14  47.669083  75.869116  65.749862  45.124030

# %% [markdown]
# **Selecting rows based on Conditional Logic**

# %%
df['Education'] > 79 # returns a 'mask' of 'True'/'False' values
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35     True
# 36    False
# 37    False
# 38     True
# 39     True
# 40     True
# 41     True
# Name: Education, dtype: bool

# %%
df[df['Education'] > 79] # only return the 'True' values
# Out:
#     Year  Agriculture  Architecture  Art and Performance    Biology  \
# 35  2005    47.672754     43.100368                 61.4  61.500984
# 38  2008    47.570834     42.711730                 60.7  59.305765
# 39  2009    48.667224     43.348921                 61.0  58.489583
# 40  2010    48.730042     42.066721                 61.3  59.010255
# 41  2011    50.037182     42.773438                 61.2  58.742397
#
#      Business  Communications and Journalism  Computer Science  Education  \
# 35  49.791851                           63.4              20.6  79.067122
# 38  48.888027                           62.4              17.8  79.196327
# 39  48.840474                           62.8              18.1  79.532909
# 40  48.757988                           62.5              17.6  79.618625
# 41  48.180418                           62.2              18.2  79.432812
#
#     Engineering    English  Foreign Languages  Health Professions  \
# 35         17.9  68.571221               69.9                86.0
# 38         16.5  67.594028               70.2                85.2
# 39         16.8  67.969792               69.3                85.1
# 40         17.2  67.928106               69.0                85.0
# 41         17.5  68.426730               69.5                84.8
#
#     Math and Statistics  Physical Sciences  Psychology  Public Administration  \
# 35                 45.1               41.6        77.5                   81.2
# 38                 43.3               40.7        77.2                   81.7
# 39                 43.3               40.7        77.1                   82.0
# 40                 43.1               40.2        77.0                   81.7
# 41                 43.1               40.1        76.7                   81.9
#
#     Social Sciences and History
# 35                         50.0
# 38                         49.4
# 39                         49.4
# 40                         49.3
# 41                         49.2

# %%
(df['Education'] > 73) & (df['Business'] < 35)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5     False
# 6     False
# 7     False
# 8      True
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# dtype: bool

# %%
df[['Business', 'Education', 'Biology', 'Agriculture']][(df['Education'] > 73) & (df['Business'] < 35)]
# Out:
#     Business  Education    Biology  Agriculture
# 0   9.064439  74.535328  29.088363     4.229798
# 1   9.503187  74.149204  29.394403     5.452797
# 2  10.558962  73.554520  29.810221     7.420710
# 3  12.804602  73.501814  31.147915     9.653602
# 4  16.204850  73.336811  32.996183    14.074623
# 8  30.527519  73.192821  40.112496    27.146192
# 9  33.621634  73.821142  42.065551    29.633365

# %%
names = ['Cars', 'Country', 'RHD']
df = pd.read_csv('../data/cars2.csv', index_col=0, header=None, names=names)
df
# Out:
#     Cars         Country    RHD
# UK   506  United Kingdom   True
# FR   340          France  False
# PT   200        Portugal  False
# DE   320         Germany  False
# BE   222         Belgium  False

# %%
df['Country'].isin(['France', 'Belgium'])
# Out:
# UK    False
# FR     True
# PT    False
# DE    False
# BE     True
# Name: Country, dtype: bool

# %%
df[df['Country'].isin(['France', 'Belgium'])]
# Out:
#     Cars  Country    RHD
# FR   340   France  False
# BE   222  Belgium  False

# %% [markdown]
# **Reset Indices**

# %%
df = pd.read_csv('../data/percent-bachelors-degrees-women-usa.csv')
df[(df['Education'] > 79) | (df['Biology'] < 32)]
# Out:
#     Year  Agriculture  Architecture  Art and Performance    Biology  \
# 0   1970     4.229798     11.921005                 59.7  29.088363
# 1   1971     5.452797     12.003106                 59.9  29.394403
# 2   1972     7.420710     13.214594                 60.4  29.810221
# 3   1973     9.653602     14.791613                 60.2  31.147915
# 35  2005    47.672754     43.100368                 61.4  61.500984
# 38  2008    47.570834     42.711730                 60.7  59.305765
# 39  2009    48.667224     43.348921                 61.0  58.489583
# 40  2010    48.730042     42.066721                 61.3  59.010255
# 41  2011    50.037182     42.773438                 61.2  58.742397
#
#      Business  Communications and Journalism  Computer Science  Education  \
# 0    9.064439                           35.3              13.6  74.535328
# 1    9.503187                           35.5              13.6  74.149204
# 2   10.558962                           36.6              14.9  73.554520
# 3   12.804602                           38.4              16.4  73.501814
# 35  49.791851                           63.4              20.6  79.067122
# 38  48.888027                           62.4              17.8  79.196327
# 39  48.840474                           62.8              18.1  79.532909
# 40  48.757988                           62.5              17.6  79.618625
# 41  48.180418                           62.2              18.2  79.432812
#
#     Engineering    English  Foreign Languages  Health Professions  \
# 0           0.8  65.570923               73.8                77.1
# 1           1.0  64.556485               73.9                75.5
# 2           1.2  63.664263               74.6                76.9
# 3           1.6  62.941502               74.9                77.4
# 35         17.9  68.571221               69.9                86.0
# 38         16.5  67.594028               70.2                85.2
# 39         16.8  67.969792               69.3                85.1
# 40         17.2  67.928106               69.0                85.0
# 41         17.5  68.426730               69.5                84.8
#
#     Math and Statistics  Physical Sciences  Psychology  Public Administration  \
# 0                  38.0               13.8        44.4                   68.4
# 1                  39.0               14.9        46.2                   65.5
# 2                  40.2               14.8        47.6                   62.6
# 3                  40.9               16.5        50.4                   64.3
# 35                 45.1               41.6        77.5                   81.2
# 38                 43.3               40.7        77.2                   81.7
# 39                 43.3               40.7        77.1                   82.0
# 40                 43.1               40.2        77.0                   81.7
# 41                 43.1               40.1        76.7                   81.9
#
#     Social Sciences and History
# 0                          36.8
# 1                          36.2
# 2                          36.1
# 3                          36.4
# 35                         50.0
# 38                         49.4
# 39                         49.4
# 40                         49.3
# 41                         49.2

# %%
df[(df['Education'] > 79) | (df['Biology'] < 32)].reset_index(drop=True)
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business  \
# 0  1970     4.229798     11.921005                 59.7  29.088363   9.064439
# 1  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 2  1972     7.420710     13.214594                 60.4  29.810221  10.558962
# 3  1973     9.653602     14.791613                 60.2  31.147915  12.804602
# 4  2005    47.672754     43.100368                 61.4  61.500984  49.791851
# 5  2008    47.570834     42.711730                 60.7  59.305765  48.888027
# 6  2009    48.667224     43.348921                 61.0  58.489583  48.840474
# 7  2010    48.730042     42.066721                 61.3  59.010255  48.757988
# 8  2011    50.037182     42.773438                 61.2  58.742397  48.180418
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.5              13.6  74.149204          1.0
# 2                           36.6              14.9  73.554520          1.2
# 3                           38.4              16.4  73.501814          1.6
# 4                           63.4              20.6  79.067122         17.9
# 5                           62.4              17.8  79.196327         16.5
# 6                           62.8              18.1  79.532909         16.8
# 7                           62.5              17.6  79.618625         17.2
# 8                           62.2              18.2  79.432812         17.5
#
#      English  Foreign Languages  Health Professions  Math and Statistics  \
# 0  65.570923               73.8                77.1                 38.0
# 1  64.556485               73.9                75.5                 39.0
# 2  63.664263               74.6                76.9                 40.2
# 3  62.941502               74.9                77.4                 40.9
# 4  68.571221               69.9                86.0                 45.1
# 5  67.594028               70.2                85.2                 43.3
# 6  67.969792               69.3                85.1                 43.3
# 7  67.928106               69.0                85.0                 43.1
# 8  68.426730               69.5                84.8                 43.1
#
#    Physical Sciences  Psychology  Public Administration  \
# 0               13.8        44.4                   68.4
# 1               14.9        46.2                   65.5
# 2               14.8        47.6                   62.6
# 3               16.5        50.4                   64.3
# 4               41.6        77.5                   81.2
# 5               40.7        77.2                   81.7
# 6               40.7        77.1                   82.0
# 7               40.2        77.0                   81.7
# 8               40.1        76.7                   81.9
#
#    Social Sciences and History
# 0                         36.8
# 1                         36.2
# 2                         36.1
# 3                         36.4
# 4                         50.0
# 5                         49.4
# 6                         49.4
# 7                         49.3
# 8                         49.2

# %%
df_tools = pd.DataFrame([
  [1, '3 inch screw', 0.5, 0.75],
  [2, '2 inch nail', 0.10, 0.25],
  [3, 'hammer', 3.00, 5.50],
  [4, 'screwdriver', 2.50, 3.00]
],
  columns=['Product ID', 'Description', 'Cost to Manufacture', 'Price']
)
df_tools
# Out:
#    Product ID   Description  Cost to Manufacture  Price
# 0           1  3 inch screw                  0.5   0.75
# 1           2   2 inch nail                  0.1   0.25
# 2           3        hammer                  3.0   5.50
# 3           4   screwdriver                  2.5   3.00

# %%
df_tools['isTaxed'] = [True, False, False, True]
df_tools['Rate'] = 0.2

df_tools
# Out:
#    Product ID   Description  Cost to Manufacture  Price  isTaxed  Rate
# 0           1  3 inch screw                  0.5   0.75     True   0.2
# 1           2   2 inch nail                  0.1   0.25    False   0.2
# 2           3        hammer                  3.0   5.50    False   0.2
# 3           4   screwdriver                  2.5   3.00     True   0.2

# %%
df_tools['Tax'] = df_tools.apply(lambda x: x.Price * x.Rate if x.isTaxed else 0, axis=1)
df_tools['Total'] = df_tools['Price'] + df_tools['Tax']
df_tools
# Out:
#    Product ID   Description  Cost to Manufacture  Price  isTaxed  Rate   Tax  \
# 0           1  3 inch screw                  0.5   0.75     True   0.2  0.15
# 1           2   2 inch nail                  0.1   0.25    False   0.2  0.00
# 2           3        hammer                  3.0   5.50    False   0.2  0.00
# 3           4   screwdriver                  2.5   3.00     True   0.2  0.60
#
#    Total
# 0   0.90
# 1   0.25
# 2   5.50
# 3   3.60
