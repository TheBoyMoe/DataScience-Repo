# %% [markdown]
# # Pandas Review

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

data = pd.read_csv('../data/tips.csv')
data.columns = ['bill', 'tip', 'gender', 'smoker', 'day', 'time', 'size', 'fraction']
print(data.shape)
data.head()
# Out:
# (244, 8)
#     bill   tip  gender smoker  day    time  size  fraction
# 0  16.99  1.01  Female     No  Sun  Dinner     2  0.059447
# 1  10.34  1.66    Male     No  Sun  Dinner     3  0.160542
# 2  21.01  3.50    Male     No  Sun  Dinner     3  0.166587
# 3  23.68  3.31    Male     No  Sun  Dinner     2  0.139780
# 4  24.59  3.61  Female     No  Sun  Dinner     4  0.146808

# %%
import random
# generate a random name column
first = ['tom', 'dick', 'harry', 'helen', 'jane', 'ema']
last = ['smith', 'brown', 'jones', 'green', 'white', 'watson']
data['name'] = [f'{random.choice(first)} {random.choice(last)}' for i in range(len(data))]

print(data.shape)
data.head()
# Out:
# (244, 9)
#     bill   tip  gender smoker  day    time  size  fraction        name
# 0  16.99  1.01  Female     No  Sun  Dinner     2  0.059447  dick white
# 1  10.34  1.66    Male     No  Sun  Dinner     3  0.160542   tom white
# 2  21.01  3.50    Male     No  Sun  Dinner     3  0.166587  jane jones
# 3  23.68  3.31    Male     No  Sun  Dinner     2  0.139780  dick jones
# 4  24.59  3.61  Female     No  Sun  Dinner     4  0.146808   tom brown

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 9 columns):
# bill        244 non-null float64
# tip         244 non-null float64
# gender      244 non-null object
# smoker      244 non-null object
# day         244 non-null object
# time        244 non-null object
# size        244 non-null int64
# fraction    244 non-null float64
# name        244 non-null object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 17.2+ KB

# %%
first_name = lambda string: string.split(' ')[0]
last_name = lambda string: string.split(' ')[-1]

data['first_name'] = data.name.apply(first_name)
data['last_name'] = data.name.apply(last_name)

print(data.shape)
data.head()
# Out:
# (244, 11)
#     bill   tip  gender smoker  day    time  size  fraction        name  \
# 0  16.99  1.01  Female     No  Sun  Dinner     2  0.059447  dick white
# 1  10.34  1.66    Male     No  Sun  Dinner     3  0.160542   tom white
# 2  21.01  3.50    Male     No  Sun  Dinner     3  0.166587  jane jones
# 3  23.68  3.31    Male     No  Sun  Dinner     2  0.139780  dick jones
# 4  24.59  3.61  Female     No  Sun  Dinner     4  0.146808   tom brown
#
#   first_name last_name
# 0       dick     white
# 1        tom     white
# 2       jane     jones
# 3       dick     jones
# 4        tom     brown

# %%
data['tax'] = data.bill * 0.3
data['total'] = data.bill + data.tip + data.tax

data.head()
# Out:
#     bill   tip  gender smoker  day    time  size  fraction        name  \
# 0  16.99  1.01  Female     No  Sun  Dinner     2  0.059447  dick white
# 1  10.34  1.66    Male     No  Sun  Dinner     3  0.160542   tom white
# 2  21.01  3.50    Male     No  Sun  Dinner     3  0.166587  jane jones
# 3  23.68  3.31    Male     No  Sun  Dinner     2  0.139780  dick jones
# 4  24.59  3.61  Female     No  Sun  Dinner     4  0.146808   tom brown
#
#   first_name last_name    tax   total
# 0       dick     white  5.097  23.097
# 1        tom     white  3.102  15.102
# 2       jane     jones  6.303  30.813
# 3       dick     jones  7.104  34.094
# 4        tom     brown  7.377  35.577

# %%
# add time tax where time == 'Lunch'
time_tax = lambda time: True if time == 'Lunch' else False
data['time_tax'] = data.time.apply(time_tax)
data.head()
# Out:
#     bill   tip  gender smoker  day    time  size  fraction        name  \
# 0  16.99  1.01  Female     No  Sun  Dinner     2  0.059447  dick white
# 1  10.34  1.66    Male     No  Sun  Dinner     3  0.160542   tom white
# 2  21.01  3.50    Male     No  Sun  Dinner     3  0.166587  jane jones
# 3  23.68  3.31    Male     No  Sun  Dinner     2  0.139780  dick jones
# 4  24.59  3.61  Female     No  Sun  Dinner     4  0.146808   tom brown
#
#   first_name last_name    tax   total  time_tax
# 0       dick     white  5.097  23.097     False
# 1        tom     white  3.102  15.102     False
# 2       jane     jones  6.303  30.813     False
# 3       dick     jones  7.104  34.094     False
# 4        tom     brown  7.377  35.577     False

# %%
# use 'axis=1' with 'apply()' to pass the entire row to lambda
meal_tax = lambda row: row.bill * 0.2 if row.time_tax else 0
data['meal_tax'] = data.apply(meal_tax, axis=1)
print(data.meal_tax.sum())
df = data[data.meal_tax > 0] # return those rows where the meal_tax > 0

print(df.shape)
df.head()
# Out:
# 233.494
# (68, 15)
#      bill   tip gender smoker   day   time  size  fraction         name  \
# 77  27.20  4.00   Male     No  Thur  Lunch     4  0.147059    ema jones
# 78  22.76  3.00   Male     No  Thur  Lunch     2  0.131810   jane green
# 79  17.29  2.71   Male     No  Thur  Lunch     2  0.156738    tom white
# 80  19.44  3.00   Male    Yes  Thur  Lunch     2  0.154321  harry green
# 81  16.66  3.40   Male     No  Thur  Lunch     2  0.204082   jane green
#
#    first_name last_name    tax   total  time_tax  meal_tax
# 77        ema     jones  8.160  39.360      True     5.440
# 78       jane     green  6.828  32.588      True     4.552
# 79        tom     white  5.187  25.187      True     3.458
# 80      harry     green  5.832  28.272      True     3.888
# 81       jane     green  4.998  25.058      True     3.332

# %%
total_bill = lambda row: row.bill + row.tip + row.tax + row.meal_tax
data['total'] = data.apply(total_bill, axis=1)
df = data[data.meal_tax > 0]

print(df.shape)
df.head()
# Out:
# (68, 15)
#      bill   tip gender smoker   day   time  size  fraction         name  \
# 77  27.20  4.00   Male     No  Thur  Lunch     4  0.147059    ema jones
# 78  22.76  3.00   Male     No  Thur  Lunch     2  0.131810   jane green
# 79  17.29  2.71   Male     No  Thur  Lunch     2  0.156738    tom white
# 80  19.44  3.00   Male    Yes  Thur  Lunch     2  0.154321  harry green
# 81  16.66  3.40   Male     No  Thur  Lunch     2  0.204082   jane green
#
#    first_name last_name    tax   total  time_tax  meal_tax
# 77        ema     jones  8.160  44.800      True     5.440
# 78       jane     green  6.828  37.140      True     4.552
# 79        tom     white  5.187  28.645      True     3.458
# 80      harry     green  5.832  32.160      True     3.888
# 81       jane     green  4.998  28.390      True     3.332

# %%
# rename certain columns
data.rename(columns={'name': 'full_name', 'tax': 'general_tax'}, inplace=True)
data.columns
# Out:
# Index(['bill', 'tip', 'gender', 'smoker', 'day', 'time', 'size', 'fraction',
#        'full_name', 'first_name', 'last_name', 'general_tax', 'total',
#        'time_tax', 'meal_tax'],
#       dtype='object')

# %%
print('Total ${:0.2f}'.format(data.total.sum()))
print('Tips ${:0.2f}'.format(data.tip.sum()))
data.total.describe()
# Out:
# Total $7241.18
# Tips $731.58
# count    244.000000
# mean      29.676947
# std       12.760428
# min        4.991000
# 25%       21.046000
# 50%       26.925000
# 75%       35.869500
# max       76.053000
# Name: total, dtype: float64

# %%
data.day.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
data.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
# group by meal
data.groupby('time').total.sum()
# Out:
# time
# Dinner    5304.460
# Lunch     1936.715
# Name: total, dtype: float64

# %%
data.groupby('gender').gender.count()
# Out:
# gender
# Female     87
# Male      157
# Name: gender, dtype: int64

# %%
data.groupby('smoker').smoker.count()
# Out:
# smoker
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
data.groupby('smoker').total.sum()
# Out:
# smoker
# No     4371.887
# Yes    2869.288
# Name: total, dtype: float64

# %%
data.groupby('smoker').tip.sum()
# Out:
# smoker
# No     451.77
# Yes    279.81
# Name: tip, dtype: float64

# %%
data.groupby('day').day.count() # reurns a series
# Out:
# day
# Fri     19
# Sat     87
# Sun     76
# Thur    62
# Name: day, dtype: int64

# %%
data.groupby('day').total.sum().reset_index() # returns a dataframe
# Out:
#     day     total
# 0   Fri   493.588
# 1   Sat  2572.320
# 2   Sun  2362.698
# 3  Thur  1812.569

# %%
data.groupby(['day', 'time', 'gender', 'smoker']).total.sum()
# Out:
# day   time    gender  smoker
# Fri   Dinner  Female  No          32.825
#                       Yes         74.240
#               Male    No          50.435
#                       Yes        184.528
#       Lunch   Female  No          26.970
#                       Yes         67.650
#               Male    Yes         56.940
# Sat   Dinner  Female  No         356.585
#                       Yes        438.230
#               Male    No         933.259
#                       Yes        844.246
# Sun   Dinner  Female  No         425.612
#                       Yes        100.008
#               Male    No        1274.502
#                       Yes        562.576
# Thur  Dinner  Female  No          27.414
#       Lunch   Female  No         630.860
#                       Yes        222.725
#               Male    No         613.425
#                       Yes        318.145
# Name: total, dtype: float64

# %% [markdown]
# ### Handling multiple dataframes

# %%
df_cars = pd.read_csv('../data/cars.csv')
df_cars.columns = ['code', 'numbers', 'country', 'drives_right']
df_cars.head()
# Out:
#   code  numbers        country  drives_right
# 0   US      809  United States          True
# 1  AUS      731      Australia         False
# 2  JAP      588          Japan         False
# 3   IN       18          India         False
# 4   RU      200         Russia          True

# %%
df_cars2 = pd.read_csv('../data/cars2.csv', header=None, names=['code', 'numbers', 'country', 'drives_right'])
df_cars2.head()
# Out:
#   code  numbers         country  drives_right
# 0   UK      506  United Kingdom          True
# 1   FR      340          France         False
# 2   PT      200        Portugal         False
# 3   DE      320         Germany         False
# 4   BE      222         Belgium         False

# %%
# concat, 'stack', two data frames, drop 'index' column
data = pd.concat([df_cars, df_cars2]).reset_index(drop=True)
print(data.shape)
data
# Out:
# (12, 4)
#    code  numbers         country  drives_right
# 0    US      809   United States          True
# 1   AUS      731       Australia         False
# 2   JAP      588           Japan         False
# 3    IN       18           India         False
# 4    RU      200          Russia          True
# 5   MOR       70         Morocco          True
# 6    EG       45           Egypt          True
# 7    UK      506  United Kingdom          True
# 8    FR      340          France         False
# 9    PT      200        Portugal         False
# 10   DE      320         Germany         False
# 11   BE      222         Belgium         False

# %%
cars_exd = pd.read_csv('../data/cars_exd.csv', header=None, names=['road_tax', 'colour', 'fuel'])
print(cars_exd.shape)
cars_exd.head(2)
# Out:
# (12, 3)
#    road_tax colour    fuel
# 0      True   blue  petrol
# 1     False    red  diesel

# %%
cars_exd['country'] = data['country']
cars_exd
# Out:
#     road_tax colour    fuel         country
# 0       True   blue  petrol   United States
# 1      False    red  diesel       Australia
# 2       True  green  petrol           Japan
# 3      False   cyan  petrol           India
# 4       True   blue  diesel          Russia
# 5       True   blue  petrol         Morocco
# 6      False    red  diesel           Egypt
# 7       True  green  petrol  United Kingdom
# 8      False   cyan  petrol          France
# 9       True   blue  diesel        Portugal
# 10     False    red  diesel         Germany
# 11      True  green  petrol         Belgium

# %%
pd.merge(data, cars_exd)
# Out:
#    code  numbers         country  drives_right  road_tax colour    fuel
# 0    US      809   United States          True      True   blue  petrol
# 1   AUS      731       Australia         False     False    red  diesel
# 2   JAP      588           Japan         False      True  green  petrol
# 3    IN       18           India         False     False   cyan  petrol
# 4    RU      200          Russia          True      True   blue  diesel
# 5   MOR       70         Morocco          True      True   blue  petrol
# 6    EG       45           Egypt          True     False    red  diesel
# 7    UK      506  United Kingdom          True      True  green  petrol
# 8    FR      340          France         False     False   cyan  petrol
# 9    PT      200        Portugal         False      True   blue  diesel
# 10   DE      320         Germany         False     False    red  diesel
# 11   BE      222         Belgium         False      True  green  petrol
